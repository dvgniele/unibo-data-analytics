# %%
import random
import torch
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
import time

import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from torch.utils.data import DataLoader, TensorDataset

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
def fix_random(seed: int) -> None:
    """Fix all the possible sources of randomness.

    Args:
        seed: the seed to use.
    """
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)

    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True  # slower

# %%
SEED = 1038893

fix_random(SEED)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device: {}".format(device))

root = "../../data/ml-25m"
# Out:
# Device: cuda

# %% [markdown]
# ## Data Acquisition

# %%
def get_data_from_csv(file: str, nrows=None):
    if nrows:
        df = pd.read_csv(f"{root}/{file}", nrows=nrows)
    else:
        df = pd.read_csv(f"{root}/{file}")
    print(f"Loaded ml-25m data: {root}/{file}")

    return df

def get_ratings_from_csv(nrows=None):
    path = "ratings.csv"

    data = get_data_from_csv(path, nrows)
    # data = get_data_from_csv(path)

    data.drop("timestamp", axis=1, inplace=True)
    # todo: drop user id
    #data.drop("userId", axis=1, inplace=True)

    return data

def get_tag_relevances_from_csv(nrows=None):
    path = "genome-scores.csv"

    return get_data_from_csv(path, nrows)

# %%
genome_scores_path = "genome-scores.csv"
ratings_path = "ratings.csv"

# %%
ratings = get_ratings_from_csv()
print(ratings)
# Out:
# Loaded ml-25m data: ../../data/ml-25m/ratings.csv
#           userId  movieId  rating
# 0              1      296     5.0
# 1              1      306     3.5
# 2              1      307     5.0
# 3              1      665     5.0
# 4              1      899     3.5
# ...          ...      ...     ...
# 25000090  162541    50872     4.5
# 25000091  162541    55768     2.5
# 25000092  162541    56176     2.0
# 25000093  162541    58559     4.0
# 25000094  162541    63876     5.0
#
# [25000095 rows x 3 columns]

# %%
genome_scores = get_tag_relevances_from_csv()
print(genome_scores)
# Out:
# Loaded ml-25m data: ../../data/ml-25m/genome-scores.csv
#           movieId  tagId  relevance
# 0               1      1    0.02875
# 1               1      2    0.02375
# 2               1      3    0.06250
# 3               1      4    0.07575
# 4               1      5    0.14075
# ...           ...    ...        ...
# 15584443   206499   1124    0.11000
# 15584444   206499   1125    0.04850
# 15584445   206499   1126    0.01325
# 15584446   206499   1127    0.14025
# 15584447   206499   1128    0.03350
#
# [15584448 rows x 3 columns]

# %%
# films = get_data_from_csv(f"{root}/{ratings}")[]

# %% [markdown]
# # DATA VISUALIZATION

# %%
            # # Fill in missing values with zeros
            # X.fillna(0, inplace=True)

# %%
def addColumnOperation(ratings,X):
     # Compute the mean rating for each user
     count_rating = ratings.groupby('movieId', as_index=False)['rating'].count()
     std= ratings.groupby('movieId', as_index=False)['rating'].std()
     std.fillna(0, inplace=True)
     min_ratings= ratings.groupby('movieId', as_index=False)['rating'].min()
     max_ratings= ratings.groupby('movieId', as_index=False)['rating'].max()
     median= ratings.groupby('movieId', as_index=False)['rating'].median()
     operation = pd.DataFrame({'movieId':count_rating['movieId'],'count_rating': count_rating['rating'], 'std': std['rating'], 'min': min_ratings['rating'], 'max': max_ratings['rating'], 'median': median['rating']}) 
     X = pd.merge(X, operation, on='movieId')
     X.drop("movieId", axis=1, inplace=True)
     return X

# %% [markdown]
# # FARE TEST CON AVG, STD_DEV

# %%
class NeuralNetwork:
    def __init__(self, ratings, relevance, seed=1038893, batch_size=32, hidden_size1=64, hidden_size2=32, lr=0.001):
        # Pivot the relevance DataFrame to create a matrix of tag relevance scores for each movie
        relevance_matrix = relevance.pivot_table(index='movieId', columns='tagId', values='relevance', fill_value=0)

        # Compute the mean rating for each user
        mean_ratings = ratings.groupby('movieId', as_index=False)['rating'].mean()

        # Merge the ratings and relevance data
        X = mean_ratings.merge(relevance_matrix, on='movieId')
        #X = addColumnOperation(ratings,X)
        X.columns = X.columns.astype(str)
        
        ratings = None
        X = X.sample(frac=1,random_state=seed).reset_index(drop=True)
        #X = X.drop('movieId', axis=1)
        y = X['rating']
        X = X.drop('movieId', axis=1)
        X = X.drop('rating', axis=1)

        
        # Split the data into training and testing sets
        self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        
        self.X_test  = self.X_test.to_numpy()
        self.X_train = self.X_train.to_numpy()
            
        # Convert the data to PyTorch tensors
        self.X_train = torch.tensor(self.X_train, dtype=torch.float32)
        self.X_test = torch.tensor(self.X_test, dtype=torch.float32)
        
        self.y_test = np.array(self.y_test)
        self.y_train = np.array(self.y_train)
        
        self.y_test = torch.tensor(self.y_test, dtype=torch.float32)
        self.y_train = torch.tensor(self.y_train, dtype=torch.float32)
        
        # Define the neural network architecture
        self.model = nn.Sequential(
            nn.Linear(X.shape[1], hidden_size1),
            nn.ReLU(),
            nn.Linear(hidden_size1, hidden_size2),
            nn.ReLU(),
            nn.Linear(hidden_size2, 1)
        )

        # Move the model to the GPU
        self.model = self.model.to(device)


        if torch.cuda.is_available():
            # Move the tensors to the GPU
            self.X_train = self.X_train.to(device)
            self.X_test = self.X_test.to(device)
            self.y_train = self.y_train.to(device)
            self.y_test = self.y_test.to(device)

        # Define the loss function and optimizer
        self.criterion = nn.MSELoss()
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)

        self.batch_size = batch_size

    def train(self, num_epochs):
        # Iterate over the entire training dataset multiple times
        for epoch in range(num_epochs):
            start_time = time.time()
            # Set the model to training mode
            self.model.train()

            # Shuffle the training data
            indices = torch.randperm(len(self.X_train))
            shuffled_X = self.X_train[indices]
            shuffled_y = self.y_train[indices]

            # Divide the training data into batches
            for i in range(0, len(self.X_train), self.batch_size):
                # Zero the gradients
                self.optimizer.zero_grad()

                # Compute the forward pass
                batch_X = shuffled_X[i:i + self.batch_size]
                batch_y = shuffled_y[i:i + self.batch_size]
                #batch_X = self.X_train
                #batch_y = self.y_train
                
                outputs = self.model(batch_X)

                # Compute the loss
                loss = self.criterion(outputs.squeeze(), batch_y)

                # Compute the backward pass and update the weights
                loss.backward()
                self.optimizer.step()

            # Evaluate the model on the validation data
            self.model.eval()
            with torch.no_grad():
                val_outputs = self.model(self.X_test)
                val_loss = self.criterion(val_outputs.squeeze(), self.y_test)


            end_time = time.time()
            elapsed_time = end_time - start_time
            # Print the training and validation loss
            #print(f'Epoch {epoch + 1}/{num_epochs} - eta: {elapsed_time:.2f}s -\tTrain Loss: {loss.item():.4f}, Val Loss: {val_loss.item():.4f}')

    def test(self):
    # Set the model to evaluation mode
        self.model.eval()

        # Disable gradient calculation to speed up inference
        with torch.no_grad():
            # Compute the predictions for the test data
            y_pred = self.model(self.X_test).squeeze()

            # Compute the test loss
            test_loss = self.criterion(y_pred, self.y_test)

            # Compute the root mean squared error (RMSE) of the test predictions
            rmse = torch.sqrt(test_loss)

            # Compute the mean squared error (MSE) of the test predictions
            mse = test_loss.item()

            # Compute the mean absolute error (MAE) of the test predictions
            mae = nn.functional.l1_loss(y_pred, self.y_test).item()

            # Compute R^2 score of the test predictions
            ss_res = torch.sum(torch.square(y_pred - self.y_test))
            ss_tot = torch.sum(torch.square(self.y_test - torch.mean(self.y_test)))
            r2 = 1 - ss_res / ss_tot

            # Print the test metrics
            #print(f'Test RMSE: {rmse.item():.4f}')
            #print(f'Test MSE: {mse:.4f}')
            #print(f'Test MAE: {mae:.4f}')
            #print(f'Test R^2 score: {r2.item():.4f}')
        return  r2.item(), self.model
    
    def load(self,model):
        self.model =model

# %%
'''model = NeuralNetwork(ratings, 
                        genome_scores,
                        seed=1038893, 
                        batch_size=128, 
                        hidden_size1=64, 
                        hidden_size2=64, 
                        lr=0.0005)


model.train(100)
model.test()'''
# Out:
# 'model = NeuralNetwork(ratings, \n                        genome_scores,\n                        seed=1038893, \n                        batch_size=128, \n                        hidden_size1=64, \n                        hidden_size2=64, \n                        lr=0.0005)\n\n\nmodel.train(100)\nmodel.test()'

# %%
import itertools

batchsize = [256]	
hidden_size1 = [64,128,256]
hidden_size2 = [64,128,256]
lr = [0.0001,0.001,0.01]
num_epochs = [200,400,600]


best_model_params = None 
best_r2 = 0

total_iterations = len(batchsize) * len(hidden_size1) * len(hidden_size2) * len(lr) * len(num_epochs)
current_iteration = 0


for batchsize,hidden_size1,hidden_size2,lr,num_epochs in itertools.product(batchsize,hidden_size1,hidden_size2,lr,num_epochs):
    current_iteration += 1
    print(f'[{current_iteration}/{total_iterations}] START => batchsize: {batchsize}, hidden_size1: {hidden_size1}, hidden_size2: {hidden_size2}, lr: {lr}, num_epochs: {num_epochs}')
    model = NeuralNetwork(ratings, 
                        genome_scores,
                        seed=1038893, 
                        batch_size=batchsize, 
                        hidden_size1=hidden_size1, 
                        hidden_size2=hidden_size2, 
                        lr=lr)
    
    
    model.train(num_epochs)
    r2, model_instance  = model.test()
    print(f'DONE: {r2} => batchsize: {batchsize}, hidden_size1: {hidden_size1}, hidden_size2: {hidden_size2}, lr: {lr}, num_epochs: {num_epochs}')
    
    #Se lo voglio caricare uso torch.load('modello.pt')
    if r2 > best_r2:
        best_r2 = r2
        best_model_params = f'{batchsize}_{hidden_size1}_{hidden_size2}_{lr}_{num_epochs}'
        torch.save(model_instance, f'model\model_{batchsize}_{hidden_size1}_{hidden_size2}_{lr}_{num_epochs}.pt')
        print(f'New best model: {best_model_params}')
    
print('============================================================')
model = NeuralNetwork(ratings,genome_scores)
print(f'Best model SCORE: {best_r2}')
model.load(torch.load(f'model/model_{best_model_params}.pt'));
print(model.test())
# Out:
# [1/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 64, lr: 0.0001, num_epochs: 200
# DONE: 0.9612724781036377 => batchsize: 256, hidden_size1: 64, hidden_size2: 64, lr: 0.0001, num_epochs: 200
# New best model: 256_64_64_0.0001_200
# [2/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 64, lr: 0.0001, num_epochs: 400
# DONE: 0.9527642130851746 => batchsize: 256, hidden_size1: 64, hidden_size2: 64, lr: 0.0001, num_epochs: 400
# [3/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 64, lr: 0.0001, num_epochs: 600
# DONE: 0.9516519904136658 => batchsize: 256, hidden_size1: 64, hidden_size2: 64, lr: 0.0001, num_epochs: 600
# [4/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 64, lr: 0.001, num_epochs: 200
# DONE: 0.9739168286323547 => batchsize: 256, hidden_size1: 64, hidden_size2: 64, lr: 0.001, num_epochs: 200
# New best model: 256_64_64_0.001_200
# [5/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 64, lr: 0.001, num_epochs: 400
# DONE: 0.9673860669136047 => batchsize: 256, hidden_size1: 64, hidden_size2: 64, lr: 0.001, num_epochs: 400
# [6/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 64, lr: 0.001, num_epochs: 600
# DONE: 0.9625444412231445 => batchsize: 256, hidden_size1: 64, hidden_size2: 64, lr: 0.001, num_epochs: 600
# [7/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 64, lr: 0.01, num_epochs: 200
# DONE: 0.9581454992294312 => batchsize: 256, hidden_size1: 64, hidden_size2: 64, lr: 0.01, num_epochs: 200
# [8/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 64, lr: 0.01, num_epochs: 400
# DONE: 0.9675889015197754 => batchsize: 256, hidden_size1: 64, hidden_size2: 64, lr: 0.01, num_epochs: 400
# [9/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 64, lr: 0.01, num_epochs: 600
# DONE: 0.9644959568977356 => batchsize: 256, hidden_size1: 64, hidden_size2: 64, lr: 0.01, num_epochs: 600
# [10/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 128, lr: 0.0001, num_epochs: 200
# DONE: 0.9601893424987793 => batchsize: 256, hidden_size1: 64, hidden_size2: 128, lr: 0.0001, num_epochs: 200
# [11/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 128, lr: 0.0001, num_epochs: 400
# DONE: 0.9528743028640747 => batchsize: 256, hidden_size1: 64, hidden_size2: 128, lr: 0.0001, num_epochs: 400
# [12/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 128, lr: 0.0001, num_epochs: 600
# DONE: 0.9516852498054504 => batchsize: 256, hidden_size1: 64, hidden_size2: 128, lr: 0.0001, num_epochs: 600
# [13/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 128, lr: 0.001, num_epochs: 200
# DONE: 0.9642807841300964 => batchsize: 256, hidden_size1: 64, hidden_size2: 128, lr: 0.001, num_epochs: 200
# [14/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 128, lr: 0.001, num_epochs: 400
# DONE: 0.9658890962600708 => batchsize: 256, hidden_size1: 64, hidden_size2: 128, lr: 0.001, num_epochs: 400
# [15/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 128, lr: 0.001, num_epochs: 600
# DONE: 0.9676020741462708 => batchsize: 256, hidden_size1: 64, hidden_size2: 128, lr: 0.001, num_epochs: 600
# [16/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 128, lr: 0.01, num_epochs: 200
# DONE: 0.971583366394043 => batchsize: 256, hidden_size1: 64, hidden_size2: 128, lr: 0.01, num_epochs: 200
# [17/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 128, lr: 0.01, num_epochs: 400
# DONE: 0.9568052291870117 => batchsize: 256, hidden_size1: 64, hidden_size2: 128, lr: 0.01, num_epochs: 400
# [18/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 128, lr: 0.01, num_epochs: 600
# DONE: 0.9670325517654419 => batchsize: 256, hidden_size1: 64, hidden_size2: 128, lr: 0.01, num_epochs: 600
# [19/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 256, lr: 0.0001, num_epochs: 200
# DONE: 0.9609250426292419 => batchsize: 256, hidden_size1: 64, hidden_size2: 256, lr: 0.0001, num_epochs: 200
# [20/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 256, lr: 0.0001, num_epochs: 400
# DONE: 0.9598535895347595 => batchsize: 256, hidden_size1: 64, hidden_size2: 256, lr: 0.0001, num_epochs: 400
# [21/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 256, lr: 0.0001, num_epochs: 600
# DONE: 0.9494209885597229 => batchsize: 256, hidden_size1: 64, hidden_size2: 256, lr: 0.0001, num_epochs: 600
# [22/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 256, lr: 0.001, num_epochs: 200
# DONE: 0.9727743864059448 => batchsize: 256, hidden_size1: 64, hidden_size2: 256, lr: 0.001, num_epochs: 200
# [23/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 256, lr: 0.001, num_epochs: 400
# DONE: 0.970643937587738 => batchsize: 256, hidden_size1: 64, hidden_size2: 256, lr: 0.001, num_epochs: 400
# [24/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 256, lr: 0.001, num_epochs: 600
# DONE: 0.9697957634925842 => batchsize: 256, hidden_size1: 64, hidden_size2: 256, lr: 0.001, num_epochs: 600
# [25/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 256, lr: 0.01, num_epochs: 200
# DONE: 0.9729862213134766 => batchsize: 256, hidden_size1: 64, hidden_size2: 256, lr: 0.01, num_epochs: 200
# [26/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 256, lr: 0.01, num_epochs: 400
# DONE: 0.9693269729614258 => batchsize: 256, hidden_size1: 64, hidden_size2: 256, lr: 0.01, num_epochs: 400
# [27/81] START => batchsize: 256, hidden_size1: 64, hidden_size2: 256, lr: 0.01, num_epochs: 600
# DONE: 0.9685852527618408 => batchsize: 256, hidden_size1: 64, hidden_size2: 256, lr: 0.01, num_epochs: 600
# [28/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 64, lr: 0.0001, num_epochs: 200
# DONE: 0.955055296421051 => batchsize: 256, hidden_size1: 128, hidden_size2: 64, lr: 0.0001, num_epochs: 200
# [29/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 64, lr: 0.0001, num_epochs: 400
# DONE: 0.9540213942527771 => batchsize: 256, hidden_size1: 128, hidden_size2: 64, lr: 0.0001, num_epochs: 400
# [30/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 64, lr: 0.0001, num_epochs: 600
# DONE: 0.9540123343467712 => batchsize: 256, hidden_size1: 128, hidden_size2: 64, lr: 0.0001, num_epochs: 600
# [31/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 64, lr: 0.001, num_epochs: 200
# DONE: 0.9644216895103455 => batchsize: 256, hidden_size1: 128, hidden_size2: 64, lr: 0.001, num_epochs: 200
# [32/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 64, lr: 0.001, num_epochs: 400
# DONE: 0.9615824818611145 => batchsize: 256, hidden_size1: 128, hidden_size2: 64, lr: 0.001, num_epochs: 400
# [33/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 64, lr: 0.001, num_epochs: 600
# DONE: 0.9591639041900635 => batchsize: 256, hidden_size1: 128, hidden_size2: 64, lr: 0.001, num_epochs: 600
# [34/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 64, lr: 0.01, num_epochs: 200
# DONE: 0.9707344770431519 => batchsize: 256, hidden_size1: 128, hidden_size2: 64, lr: 0.01, num_epochs: 200
# [35/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 64, lr: 0.01, num_epochs: 400
# DONE: 0.968029260635376 => batchsize: 256, hidden_size1: 128, hidden_size2: 64, lr: 0.01, num_epochs: 400
# [36/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 64, lr: 0.01, num_epochs: 600
# DONE: 0.9558796882629395 => batchsize: 256, hidden_size1: 128, hidden_size2: 64, lr: 0.01, num_epochs: 600
# [37/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 128, lr: 0.0001, num_epochs: 200
# DONE: 0.9562343955039978 => batchsize: 256, hidden_size1: 128, hidden_size2: 128, lr: 0.0001, num_epochs: 200
# [38/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 128, lr: 0.0001, num_epochs: 400
# DONE: 0.9524132609367371 => batchsize: 256, hidden_size1: 128, hidden_size2: 128, lr: 0.0001, num_epochs: 400
# [39/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 128, lr: 0.0001, num_epochs: 600
# DONE: 0.9475612044334412 => batchsize: 256, hidden_size1: 128, hidden_size2: 128, lr: 0.0001, num_epochs: 600
# [40/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 128, lr: 0.001, num_epochs: 200
# DONE: 0.9625073075294495 => batchsize: 256, hidden_size1: 128, hidden_size2: 128, lr: 0.001, num_epochs: 200
# [41/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 128, lr: 0.001, num_epochs: 400
# DONE: 0.9679384231567383 => batchsize: 256, hidden_size1: 128, hidden_size2: 128, lr: 0.001, num_epochs: 400
# [42/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 128, lr: 0.001, num_epochs: 600
# DONE: 0.9642265439033508 => batchsize: 256, hidden_size1: 128, hidden_size2: 128, lr: 0.001, num_epochs: 600
# [43/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 128, lr: 0.01, num_epochs: 200
# DONE: 0.9666237831115723 => batchsize: 256, hidden_size1: 128, hidden_size2: 128, lr: 0.01, num_epochs: 200
# [44/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 128, lr: 0.01, num_epochs: 400
# DONE: 0.9673261046409607 => batchsize: 256, hidden_size1: 128, hidden_size2: 128, lr: 0.01, num_epochs: 400
# [45/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 128, lr: 0.01, num_epochs: 600
# DONE: 0.9652052521705627 => batchsize: 256, hidden_size1: 128, hidden_size2: 128, lr: 0.01, num_epochs: 600
# [46/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 256, lr: 0.0001, num_epochs: 200
# DONE: 0.9569110870361328 => batchsize: 256, hidden_size1: 128, hidden_size2: 256, lr: 0.0001, num_epochs: 200
# [47/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 256, lr: 0.0001, num_epochs: 400
# DONE: 0.9483170509338379 => batchsize: 256, hidden_size1: 128, hidden_size2: 256, lr: 0.0001, num_epochs: 400
# [48/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 256, lr: 0.0001, num_epochs: 600
# DONE: 0.9492461085319519 => batchsize: 256, hidden_size1: 128, hidden_size2: 256, lr: 0.0001, num_epochs: 600
# [49/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 256, lr: 0.001, num_epochs: 200
# DONE: 0.9609406590461731 => batchsize: 256, hidden_size1: 128, hidden_size2: 256, lr: 0.001, num_epochs: 200
# [50/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 256, lr: 0.001, num_epochs: 400
# DONE: 0.9652594923973083 => batchsize: 256, hidden_size1: 128, hidden_size2: 256, lr: 0.001, num_epochs: 400
# [51/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 256, lr: 0.001, num_epochs: 600
# DONE: 0.9645487666130066 => batchsize: 256, hidden_size1: 128, hidden_size2: 256, lr: 0.001, num_epochs: 600
# [52/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 256, lr: 0.01, num_epochs: 200
# DONE: 0.9726552367210388 => batchsize: 256, hidden_size1: 128, hidden_size2: 256, lr: 0.01, num_epochs: 200
# [53/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 256, lr: 0.01, num_epochs: 400
# DONE: 0.9650155305862427 => batchsize: 256, hidden_size1: 128, hidden_size2: 256, lr: 0.01, num_epochs: 400
# [54/81] START => batchsize: 256, hidden_size1: 128, hidden_size2: 256, lr: 0.01, num_epochs: 600
# DONE: 0.9666996002197266 => batchsize: 256, hidden_size1: 128, hidden_size2: 256, lr: 0.01, num_epochs: 600
# [55/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 64, lr: 0.0001, num_epochs: 200
# DONE: 0.9559940695762634 => batchsize: 256, hidden_size1: 256, hidden_size2: 64, lr: 0.0001, num_epochs: 200
# [56/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 64, lr: 0.0001, num_epochs: 400
# DONE: 0.9534884095191956 => batchsize: 256, hidden_size1: 256, hidden_size2: 64, lr: 0.0001, num_epochs: 400
# [57/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 64, lr: 0.0001, num_epochs: 600
# DONE: 0.9540683627128601 => batchsize: 256, hidden_size1: 256, hidden_size2: 64, lr: 0.0001, num_epochs: 600
# [58/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 64, lr: 0.001, num_epochs: 200
# DONE: 0.9648467302322388 => batchsize: 256, hidden_size1: 256, hidden_size2: 64, lr: 0.001, num_epochs: 200
# [59/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 64, lr: 0.001, num_epochs: 400
# DONE: 0.9617657661437988 => batchsize: 256, hidden_size1: 256, hidden_size2: 64, lr: 0.001, num_epochs: 400
# [60/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 64, lr: 0.001, num_epochs: 600
# DONE: 0.9620130062103271 => batchsize: 256, hidden_size1: 256, hidden_size2: 64, lr: 0.001, num_epochs: 600
# [61/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 64, lr: 0.01, num_epochs: 200
# DONE: 0.9482433199882507 => batchsize: 256, hidden_size1: 256, hidden_size2: 64, lr: 0.01, num_epochs: 200
# [62/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 64, lr: 0.01, num_epochs: 400
# DONE: 0.9669539332389832 => batchsize: 256, hidden_size1: 256, hidden_size2: 64, lr: 0.01, num_epochs: 400
# [63/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 64, lr: 0.01, num_epochs: 600
# DONE: 0.9600746035575867 => batchsize: 256, hidden_size1: 256, hidden_size2: 64, lr: 0.01, num_epochs: 600
# [64/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 128, lr: 0.0001, num_epochs: 200
# DONE: 0.9544785618782043 => batchsize: 256, hidden_size1: 256, hidden_size2: 128, lr: 0.0001, num_epochs: 200
# [65/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 128, lr: 0.0001, num_epochs: 400
# DONE: 0.9522084593772888 => batchsize: 256, hidden_size1: 256, hidden_size2: 128, lr: 0.0001, num_epochs: 400
# [66/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 128, lr: 0.0001, num_epochs: 600
# DONE: 0.954993724822998 => batchsize: 256, hidden_size1: 256, hidden_size2: 128, lr: 0.0001, num_epochs: 600
# [67/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 128, lr: 0.001, num_epochs: 200
# DONE: 0.9589515328407288 => batchsize: 256, hidden_size1: 256, hidden_size2: 128, lr: 0.001, num_epochs: 200
# [68/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 128, lr: 0.001, num_epochs: 400
# DONE: 0.9600842595100403 => batchsize: 256, hidden_size1: 256, hidden_size2: 128, lr: 0.001, num_epochs: 400
# [69/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 128, lr: 0.001, num_epochs: 600
# DONE: 0.9607933759689331 => batchsize: 256, hidden_size1: 256, hidden_size2: 128, lr: 0.001, num_epochs: 600
# [70/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 128, lr: 0.01, num_epochs: 200
# DONE: 0.9766085147857666 => batchsize: 256, hidden_size1: 256, hidden_size2: 128, lr: 0.01, num_epochs: 200
# New best model: 256_256_128_0.01_200
# [71/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 128, lr: 0.01, num_epochs: 400
# DONE: 0.9706481099128723 => batchsize: 256, hidden_size1: 256, hidden_size2: 128, lr: 0.01, num_epochs: 400
# [72/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 128, lr: 0.01, num_epochs: 600
# DONE: 0.9687760472297668 => batchsize: 256, hidden_size1: 256, hidden_size2: 128, lr: 0.01, num_epochs: 600
# [73/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 256, lr: 0.0001, num_epochs: 200
# DONE: 0.9526845812797546 => batchsize: 256, hidden_size1: 256, hidden_size2: 256, lr: 0.0001, num_epochs: 200
# [74/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 256, lr: 0.0001, num_epochs: 400
# DONE: 0.9533652067184448 => batchsize: 256, hidden_size1: 256, hidden_size2: 256, lr: 0.0001, num_epochs: 400
# [75/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 256, lr: 0.0001, num_epochs: 600
# DONE: 0.9549418091773987 => batchsize: 256, hidden_size1: 256, hidden_size2: 256, lr: 0.0001, num_epochs: 600
# [76/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 256, lr: 0.001, num_epochs: 200
# DONE: 0.9654757380485535 => batchsize: 256, hidden_size1: 256, hidden_size2: 256, lr: 0.001, num_epochs: 200
# [77/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 256, lr: 0.001, num_epochs: 400
# DONE: 0.9628311991691589 => batchsize: 256, hidden_size1: 256, hidden_size2: 256, lr: 0.001, num_epochs: 400
# [78/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 256, lr: 0.001, num_epochs: 600
# DONE: 0.9680607318878174 => batchsize: 256, hidden_size1: 256, hidden_size2: 256, lr: 0.001, num_epochs: 600
# [79/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 256, lr: 0.01, num_epochs: 200
# DONE: 0.9687849879264832 => batchsize: 256, hidden_size1: 256, hidden_size2: 256, lr: 0.01, num_epochs: 200
# [80/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 256, lr: 0.01, num_epochs: 400
# DONE: 0.9730878472328186 => batchsize: 256, hidden_size1: 256, hidden_size2: 256, lr: 0.01, num_epochs: 400
# [81/81] START => batchsize: 256, hidden_size1: 256, hidden_size2: 256, lr: 0.01, num_epochs: 600
# DONE: -0.004492282867431641 => batchsize: 256, hidden_size1: 256, hidden_size2: 256, lr: 0.01, num_epochs: 600
# ============================================================
# Best model SCORE: 0.9766085147857666
# (0.9766085147857666, Sequential(
#   (0): Linear(in_features=1128, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=128, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=128, out_features=1, bias=True)
# ))

# %%
#
#model = NeuralNetwork(ratings,genome_scores)
#model.load(torch.load('model/model_128_64_64_0.0001_10.pt'));
#print(model.test())
